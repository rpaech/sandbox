# %%
mylist = range(10)
for i in mylist:
    print('{} in {}'.format(i, i**2))
# Out:
# 0 in 0
# 1 in 1
# 2 in 4
# 3 in 9
# 4 in 16
# 5 in 25
# 6 in 36
# 7 in 49
# 8 in 64
# 9 in 81

# %%
import sys
sys.version
# Out:
# '3.7.10 (default, Feb 20 2021, 21:17:23) \n[GCC 7.5.0]'
